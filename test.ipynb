# %%
import faiss
import numpy as np

# Load the saved FAISS index
index = faiss.read_index("books.faiss")

print(f"Index loaded: {index.ntotal} vectors, dim={index.d}")
# Out:
# Index loaded: 40 vectors, dim=384
